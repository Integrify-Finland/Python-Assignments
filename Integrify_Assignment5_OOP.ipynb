# %% [markdown]
# # Integrify Assignment 5
#
# ## Python Basics: OOP
# ### Date: 2023.03.19

# %% [markdown]
# ## Task 1
# **OOP**
#
# Everything in python is class and object. Let's verify that. Run the following code:
#
# ![image.png](attachment:image.png)

# %%
a=5
b="some string"
print(type(a), type(b))

def someFunction():
    return

class Someclass():
    pass

someList=[int, str, tuple, dict, list, print, someFunction, Someclass]
for item in someList:
    print(type(item))
# Out:
# <class 'int'> <class 'str'>
# <class 'type'>
# <class 'type'>
# <class 'type'>
# <class 'type'>
# <class 'type'>
# <class 'builtin_function_or_method'>
# <class 'function'>
# <class 'type'>

# %% [markdown]
# ### Task 2
# **Compare the result of step a and step b:**
#
# ![image.png](attachment:image.png)

# %%
# Create an object of each item in the list
anotherList=[int(), str(), tuple(), dict(), list(), print(), someFunction(), Someclass()]
for item in anotherList:
    print(type(item))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'tuple'>
# <class 'dict'>
# <class 'list'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class '__main__.Someclass'>

# %% [markdown]
# ### Task 3
# Create two classes Pet and Dog
#
# - Requirements for Pet class
#
#    i. Three class attributes pet_population , pet_instance and current_year
#
#    ii. Init constructor __init__(self,name,category,age), name is name of pet,category could be dog,cat,bird etc. and age is age of pet
#
#    iii. An instance method hellofrompet that prints hello from petname
#
#    iv. Create a class method timepassedby which takes years as argumentshould automatically increase the age of all the pet object as soon as the method is applied
#
# pet_population should show the number of pets created and pet_instance is the list of pet object
# - Requirements for Dog class
#    1. Dog class should inherit Pet class attributes and methods. Apart from that the init constructor takes addition "breed" argument
#    2. Define the instance method barks which displays the breed does woof woof.
#
# Validate your code: Run the following piece of code
#
# ![image.png](attachment:image.png)

# %%
class Pet:
    # i. Three class attributes pet_population, pet_instance and current_year
    # pet_population should show the number of pets created and pet_instance is the list of pet object
    pet_population = 0
    pet_instances = []
    current_year = 0
    
    # ii. Init constructor init(self,name,category,age), name is name of pet,
    #category could be dog,cat,bird etc. and age is age of pet
    def __init__(self, name, category, age):
        self.name = name
        self.category = category
        self.age = age
        # increment of a class attribute everytime an object is created (eg : a new Pet or Dog)
        Pet.pet_population += 1
        #Pet.pet_instances.append(name)
    
    # iii. An instance method hellofrompet that prints hello from pet name
    # Instance Method
    def say_hello(self):  
        print('Hello, my name is', self.name)
        
    # iv. Create a class method time_passed_by which takes years as argument 
    # should automatically increase the age of all the pet object as soon as the method is applied
    # Instance Method
    def timepassedby(self, years):
        self.age += years
        #for item in self.age:
            #item.timepassedby(years)

# Dog class should inherit Pet class attributes and methods.
# Apart from that the init constructor takes addition "breed" argument      
class Dog(Pet):
    def __init__(self, name, category, age, breed):
        super().__init__(name, category, age)
        self.breed = breed
    
    # Instance Method
    # Define the instance method barks which displays the breed does woof woof.
    def barks(self):  
        print("The {} goes 'woof woof'".format(self.breed))

# %%
# Create the Pet instance
instance1=Pet("Micky", "Cat", 1)
# Create Dog instance
instance2=Dog("Saphie", "Dog", 2, "German Shepherd")

# Running the Pet.pet_population and Dog.pet_population should return 2
print(Pet.pet_population)
print(Dog.pet_population)

# Display all the names of the Pets: should return Micky and Saphie
Pet.pet_instances.append(instance1)
Pet.pet_instances.append(instance2)
#print(Pet.pet_instances)
for item in Pet.pet_instances:
    print(item.name)

#print(Pet)
instances = [instance1, instance2]
for Pets in instances:  
    # Pet.timepassedby(5) should increase every pet age by 5
    Pets.timepassedby(5)
print(instance1.age) # should give the value 6
print(instance2.age) # should give the value 7

#instance1.barks()
instance2.barks()
# Out:
# 2
# 2
# Micky
# Saphie
# 6
# 7
# The German Shepherd goes 'woof woof'

# %% [markdown]
# ## The End of Assignment 5
